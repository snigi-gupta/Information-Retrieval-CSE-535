# %%
import json
import re


twitter_user = "AmitShah"
# jairbolsonaro for e 10 - 13
# narendramodi for # and @ and url 0-3

with open("crawledData/"+twitter_user+".json", "r") as f:
    data = json.load(f)

# slice data
# s = slice(0,1)
# data = data[s]

i=0
# get stopwords

for tweet in data:
    i=i+1
    fillers = []
    mu=0
    temp_text = tweet.get('tweet_text')
    fillers.extend(["#"+h for h in tweet.get('hashtags')])
    fillers.extend(["@"+m for m in tweet.get('mentions')])
    fillers.extend([u for u in tweet.get('tweet_urls')])
    fillers.extend(tweet.get('tweet_emoticons'))
    try:
        fillers.extend([mu for mu in tweet.get('media_url')])
    except Exception as e:
        pass
#     print(fillers)
    
    for filler in fillers:
#         print("filler",filler)
#         print("temp_text:\n",temp_text)
#         print("----------------------")
        temp_text = re.sub(filler,'',temp_text)
#         print(temp_text)
#         print("new_text:\n",temp_text)
#         print("----------------------")
    
    if tweet.get('tweet_lang') == "en":
        tweet.update({"text_en":temp_text})

    if tweet.get('tweet_lang') == "hi":
        tweet.update({"text_hi":temp_text})

    if tweet.get('tweet_lang') == "pt":
        tweet.update({"text_pt":temp_text})
        
#     break
#     print(tweet.get('poi_name'),"TweetID ",i)
#     print("-------------------")
#     print(tweet.get('tweet_text'))
#     print("-------------------")
#     print(tweet.get('text_en'))
#     print(tweet.get('text_hi'))
#     print(tweet.get('text_pt'))
    
#     print("*******************")
    
with open("cleanedCrawledData/"+twitter_user+".json","w") as f:
    json.dump(data,f)

print("DONE!")
# Out:
# DONE!

# %%
# clean tweets: set country
import json
with open("crawledData/HillaryClinton.json","r") as f:
    data = json.load(f)

for d in data:
    d.update({'country': "usa"})

with open("crawledData/HillaryClinton1.json","w") as f:
    json.dump(data,f)
print('Done')
# Out:
# Done

# %%
# clean tweets: add key
import json

twitter_user = "AmitShah"
with open("crawledData/"+twitter_user+".json","r") as f:
    data = json.load(f)
i=0
for d in data:
    i=i+1
    if d.get('in_reply_to_status_id'):
#         print(d.get('in_reply_to_status_id'))
        d.update({'reply_text':d.get('tweet_text')})
    else:
        d.update({'reply_text':None})
#         print(d)
print(i,"changes made")
with open("crawledData/"+twitter_user+"1.json","w") as f:
    json.dump(data,f)
print('Done')
# Out:
# 1911 changes made
# Done

# %%
data
# Out:
# [{'poi_name': 'realDonaldTrump',
#   'poi_id': 25073877,
#   'verified': True,
#   'country': 'Washington, DC',
#   'replied_to_tweet_id': 1169981019228913664,
#   'replied_to_user_id': 25073877,
#   'tweet_text': '....Epic!ðŸ˜‚ðŸ˜‚...Epic!ðŸ˜‚ðŸ˜‚...Epic!ðŸ˜‚ðŸ˜‚...partner should start playing it straight. It would be so much better for our Country!',
#   'tweet_lang': 'en',
#   'hashtags': [],
#   'mentions': [],
#   'tweet_urls': [],
#   'tweet_date': 'Fri Sep 06 14:29:47 +0000 2019',
#   'tweet_loc': None,
#   'tweet_id': 1169981020634013696,
#   'retweeted': False,
#   'replied_to_screen_name': 'realDonaldTrump'},
#  {'poi_name': 'realDonaldTrump',
#   'poi_id': 25073877,
#   'verified': False,
#   'country': '',
#   'replied_to_tweet_id': 1169981020634013696,
#   'replied_to_user_id': 25073877,
#   'tweet_text': '@realDonaldTrump You are one HUGE Embarrassment to America! https://t.co/DK4eMjRqZ3',
#   'tweet_lang': 'en',
#   'hashtags': [],
#   'mentions': [{'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [0, 16]}],
#   'tweet_urls': [],
#   'tweet_date': 'Fri Sep 06 14:35:48 +0000 2019',
#   'tweet_loc': None,
#   'tweet_id': 1169982535599906816,
#   'retweeted': False,
#   'replied_to_screen_name': 'realDonaldTrump'},
#  {'poi_name': 'realDonaldTrump',
#   'poi_id': 25073877,
#   'verified': False,
#   'country': 'Chicago, IL',
#   'replied_to_tweet_id': 1169981020634013696,
#   'replied_to_user_id': 25073877,
#   'tweet_text': '@realDonaldTrump #sharpiegate',
#   'tweet_lang': 'und',
#   'hashtags': [{'text': 'sharpiegate', 'indices': [17, 29]}],
#   'mentions': [{'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [0, 16]}],
#   'tweet_urls': [],
#   'tweet_date': 'Fri Sep 06 14:35:46 +0000 2019',
#   'tweet_loc': None,
#   'tweet_id': 1169982527794290689,
#   'retweeted': False,
#   'replied_to_screen_name': 'realDonaldTrump'},
#  {'poi_name': 'realDonaldTrump',
#   'poi_id': 25073877,
#   'verified': False,
#   'country': 'California, USA',
#   'replied_to_tweet_id': 1169981020634013696,
#   'replied_to_user_id': 25073877,
#   'tweet_text': '@realDonaldTrump Maybe showing your birth certificate would help. It helped the last time a President was ACTUALLY treated unfairly.',
#   'tweet_lang': 'en',
#   'hashtags': [],
#   'mentions': [{'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [0, 16]}],
#   'tweet_urls': [],
#   'tweet_date': 'Fri Sep 06 14:35:45 +0000 2019',
#   'tweet_loc': None,
#   'tweet_id': 1169982522148569089,
#   'retweeted': False,
#   'replied_to_screen_name': 'realDonaldTrump'},
#  {'poi_name': 'realDonaldTrump',
#   'poi_id': 25073877,
#   'verified': False,
#   'country': 'MN',
#   'replied_to_tweet_id': 1169981020634013696,
#   'replied_to_user_id': 25073877,
#   'tweet_text': '@realDonaldTrump #MAGA #sharpiegate https://t.co/P5KUEXDzTC',
#   'tweet_lang': 'und',
#   'hashtags': [{'text': 'MAGA', 'indices': [17, 22]},
#    {'text': 'sharpiegate', 'indices': [23, 35]}],
#   'mentions': [{'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [0, 16]}],
#   'tweet_urls': [],
#   'tweet_date': 'Fri Sep 06 14:35:44 +0000 2019',
#   'tweet_loc': None,
#   'tweet_id': 1169982521171333120,
#   'retweeted': False,
#   'replied_to_screen_name': 'realDonaldTrump'},
#  {'poi_name': 'realDonaldTrump',
#   'poi_id': 25073877,
#   'verified': False,
#   'country': '',
#   'replied_to_tweet_id': 1169981020634013696,
#   'replied_to_user_id': 25073877,
#   'tweet_text': '@realDonaldTrump Leave weather reporting to meteorologists and the meteorologists will not act as president of the USA. Deal?',
#   'tweet_lang': 'en',
#   'hashtags': [],
#   'mentions': [{'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [0, 16]}],
#   'tweet_urls': [],
#   'tweet_date': 'Fri Sep 06 14:35:44 +0000 2019',
#   'tweet_loc': None,
#   'tweet_id': 1169982520282271744,
#   'retweeted': False,
#   'replied_to_screen_name': 'realDonaldTrump'},
#  {'poi_name': 'realDonaldTrump',
#   'poi_id': 25073877,
#   'verified': False,
#   'country': 'United States',
#   'replied_to_tweet_id': 1169981020634013696,
#   'replied_to_user_id': 25073877,
#   'tweet_text': '@realDonaldTrump https://t.co/LBNZ2XPRl7',
#   'tweet_lang': 'und',
#   'hashtags': [],
#   'mentions': [{'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [0, 16]}],
#   'tweet_urls': [],
#   'tweet_date': 'Fri Sep 06 14:35:43 +0000 2019',
#   'tweet_loc': None,
#   'tweet_id': 1169982514435252229,
#   'retweeted': False,
#   'replied_to_screen_name': 'realDonaldTrump'},
#  {'poi_name': 'realDonaldTrump',
#   'poi_id': 25073877,
#   'verified': False,
#   'country': 'USA',
#   'replied_to_tweet_id': 1169981020634013696,
#   'replied_to_user_id': 25073877,
#   'tweet_text': '@realDonaldTrump The best thing for our country is for you and your mob family to get the hell out of OUR White House.',
#   'tweet_lang': 'en',
#   'hashtags': [],
#   'mentions': [{'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [0, 16]}],
#   'tweet_urls': [],
#   'tweet_date': 'Fri Sep 06 14:35:42 +0000 2019',
#   'tweet_loc': None,
#   'tweet_id': 1169982512380174336,
#   'retweeted': False,
#   'replied_to_screen_name': 'realDonaldTrump'},
#  {'poi_name': 'realDonaldTrump',
#   'poi_id': 25073877,
#   'verified': False,
#   'country': '',
#   'replied_to_tweet_id': 1169981020634013696,
#   'replied_to_user_id': 25073877,
#   'tweet_text': '@realDonaldTrump So, Mr. Woe is me, strongman, do you really have no ability to move on from this, or are you planning on giving #Alabama some #FEMA funds, so you have to justify the state being a possible target...? All to make up for the taxes, and military projects you took from those people.',
#   'tweet_lang': 'en',
#   'hashtags': [{'text': 'Alabama', 'indices': [129, 137]},
#    {'text': 'FEMA', 'indices': [143, 148]}],
#   'mentions': [{'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [0, 16]}],
#   'tweet_urls': [],
#   'tweet_date': 'Fri Sep 06 14:35:41 +0000 2019',
#   'tweet_loc': None,
#   'tweet_id': 1169982507539939330,
#   'retweeted': False,
#   'replied_to_screen_name': 'realDonaldTrump'},
#  {'poi_name': 'realDonaldTrump',
#   'poi_id': 25073877,
#   'verified': False,
#   'country': 'Santa Carla, CA',
#   'replied_to_tweet_id': 1169981020634013696,
#   'replied_to_user_id': 25073877,
#   'tweet_text': '@realDonaldTrump https://t.co/0b3OYYrcEd',
#   'tweet_lang': 'und',
#   'hashtags': [],
#   'mentions': [{'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [0, 16]}],
#   'tweet_urls': [],
#   'tweet_date': 'Fri Sep 06 14:35:41 +0000 2019',
#   'tweet_loc': None,
#   'tweet_id': 1169982505031569408,
#   'retweeted': False,
#   'replied_to_screen_name': 'realDonaldTrump'},
#  {'poi_name': 'realDonaldTrump',
#   'poi_id': 25073877,
#   'verified': False,
#   'country': '',
#   'replied_to_tweet_id': 1169981020634013696,
#   'replied_to_user_id': 25073877,
#   'tweet_text': '@realDonaldTrump It would be nice if the media just “played it straight” with you; e.g., when you lie, call it a lie, not a misstatement. Call your corruption that, bluntly.  When you appoint a crook, call that person a crook.  Tell the truth about your hair, your makeup, your “executive time.”',
#   'tweet_lang': 'en',
#   'hashtags': [],
#   'mentions': [{'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [0, 16]}],
#   'tweet_urls': [],
#   'tweet_date': 'Fri Sep 06 14:35:40 +0000 2019',
#   'tweet_loc': None,
#   'tweet_id': 1169982502628466688,
#   'retweeted': False,
#   'replied_to_screen_name': 'realDonaldTrump'},
#  {'poi_name': 'realDonaldTrump',
#   'poi_id': 25073877,
#   'verified': False,
#   'country': '',
#   'replied_to_tweet_id': 1169981020634013696,
#   'replied_to_user_id': 25073877,
#   'tweet_text': '@realDonaldTrump 🙄\nDorian made landfall in North Carolina. You really don’t care. Do you!',
#   'tweet_lang': 'en',
#   'hashtags': [],
#   'mentions': [{'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [0, 16]}],
#   'tweet_urls': [],
#   'tweet_date': 'Fri Sep 06 14:35:37 +0000 2019',
#   'tweet_loc': None,
#   'tweet_id': 1169982490678910976,
#   'retweeted': False,
#   'replied_to_screen_name': 'realDonaldTrump'},
#  {'poi_name': 'realDonaldTrump',
#   'poi_id': 25073877,
#   'verified': False,
#   'country': 'Planet Earth 🌍Virginia ',
#   'replied_to_tweet_id': 1169981020634013696,
#   'replied_to_user_id': 25073877,
#   'tweet_text': '@realDonaldTrump Malignant narcissism on full display.. in other news, water is wet. 🙄 https://t.co/OUIgDvii3U',
#   'tweet_lang': 'en',
#   'hashtags': [],
#   'mentions': [{'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [0, 16]}],
#   'tweet_urls': [],
#   'tweet_date': 'Fri Sep 06 14:35:37 +0000 2019',
#   'tweet_loc': None,
#   'tweet_id': 1169982488883662850,
#   'retweeted': False,
#   'replied_to_screen_name': 'realDonaldTrump'},
#  {'poi_name': 'realDonaldTrump',
#   'poi_id': 25073877,
#   'verified': False,
#   'country': 'Bend, OR',
#   'replied_to_tweet_id': 1169981020634013696,
#   'replied_to_user_id': 25073877,
#   'tweet_text': '@realDonaldTrump Best thing for country would be if Trump shut up and crawled back under a rock',
#   'tweet_lang': 'en',
#   'hashtags': [],
#   'mentions': [{'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [0, 16]}],
#   'tweet_urls': [],
#   'tweet_date': 'Fri Sep 06 14:35:36 +0000 2019',
#   'tweet_loc': None,
#   'tweet_id': 1169982484710342658,
#   'retweeted': False,
#   'replied_to_screen_name': 'realDonaldTrump'},
#  {'poi_name': 'realDonaldTrump',
#   'poi_id': 25073877,
#   'verified': False,
#   'country': 'St. Louis, MO',
#   'replied_to_tweet_id': 1169981020634013696,
#   'replied_to_user_id': 25073877,
#   'tweet_text': '@realDonaldTrump Yes THEY are the ones fixated on it😒',
#   'tweet_lang': 'en',
#   'hashtags': [],
#   'mentions': [{'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [0, 16]}],
#   'tweet_urls': [],
#   'tweet_date': 'Fri Sep 06 14:35:36 +0000 2019',
#   'tweet_loc': None,
#   'tweet_id': 1169982484332929024,
#   'retweeted': False,
#   'replied_to_screen_name': 'realDonaldTrump'},
#  {'poi_name': 'realDonaldTrump',
#   'poi_id': 25073877,
#   'verified': False,
#   'country': 'New Jersey, USA',
#   'replied_to_tweet_id': 1169981020634013696,
#   'replied_to_user_id': 25073877,
#   'tweet_text': '@realDonaldTrump https://t.co/RGp82KAYP0',
#   'tweet_lang': 'und',
#   'hashtags': [],
#   'mentions': [{'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [0, 16]}],
#   'tweet_urls': [],
#   'tweet_date': 'Fri Sep 06 14:35:34 +0000 2019',
#   'tweet_loc': None,
#   'tweet_id': 1169982476988669953,
#   'retweeted': False,
#   'replied_to_screen_name': 'realDonaldTrump'},
#  {'poi_name': 'realDonaldTrump',
#   'poi_id': 25073877,
#   'verified': False,
#   'country': '',
#   'replied_to_tweet_id': 1169981020634013696,
#   'replied_to_user_id': 25073877,
#   'tweet_text': '@realDonaldTrump #25thAmendmentNow',
#   'tweet_lang': 'und',
#   'hashtags': [{'text': '25thAmendmentNow', 'indices': [17, 34]}],
#   'mentions': [{'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [0, 16]}],
#   'tweet_urls': [],
#   'tweet_date': 'Fri Sep 06 14:35:33 +0000 2019',
#   'tweet_loc': None,
#   'tweet_id': 1169982475063316480,
#   'retweeted': False,
#   'replied_to_screen_name': 'realDonaldTrump'},
#  {'poi_name': 'realDonaldTrump',
#   'poi_id': 25073877,
#   'verified': False,
#   'country': 'Miami, FL',
#   'replied_to_tweet_id': 1169981020634013696,
#   'replied_to_user_id': 25073877,
#   'tweet_text': '@realDonaldTrump The president is an actual loser. Wow. https://t.co/uHCDCBnH4t',
#   'tweet_lang': 'en',
#   'hashtags': [],
#   'mentions': [{'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [0, 16]}],
#   'tweet_urls': [],
#   'tweet_date': 'Fri Sep 06 14:35:33 +0000 2019',
#   'tweet_loc': None,
#   'tweet_id': 1169982473633181696,
#   'retweeted': False,
#   'replied_to_screen_name': 'realDonaldTrump'},
#  {'poi_name': 'realDonaldTrump',
#   'poi_id': 25073877,
#   'verified': False,
#   'country': '',
#   'replied_to_tweet_id': 1169981020634013696,
#   'replied_to_user_id': 25073877,
#   'tweet_text': '@realDonaldTrump You are derelict of your duties to this country.  Get off your ass, turn off the TV and get to work....then maybe you would really know what is going on rather than giving bad information to the country...and Alabama in particular...',
#   'tweet_lang': 'en',
#   'hashtags': [],
#   'mentions': [{'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [0, 16]}],
#   'tweet_urls': [],
#   'tweet_date': 'Fri Sep 06 14:35:33 +0000 2019',
#   'tweet_loc': None,
#   'tweet_id': 1169982472928616448,
#   'retweeted': False,
#   'replied_to_screen_name': 'realDonaldTrump'},
#  {'poi_name': 'realDonaldTrump',
#   'poi_id': 25073877,
#   'verified': True,
#   'country': 'New York, NY',
#   'replied_to_tweet_id': 1169981020634013696,
#   'replied_to_user_id': 25073877,
#   'tweet_text': '@realDonaldTrump Keep going man everyone thinks this is great',
#   'tweet_lang': 'en',
#   'hashtags': [],
#   'mentions': [{'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [0, 16]}],
#   'tweet_urls': [],
#   'tweet_date': 'Fri Sep 06 14:35:33 +0000 2019',
#   'tweet_loc': None,
#   'tweet_id': 1169982472911802369,
#   'retweeted': False,
#   'replied_to_screen_name': 'realDonaldTrump'},
#  {'poi_name': 'realDonaldTrump',
#   'poi_id': 25073877,
#   'verified': False,
#   'country': '',
#   'replied_to_tweet_id': 1169981020634013696,
#   'replied_to_user_id': 25073877,
#   'tweet_text': '@realDonaldTrump #FakeNewsMedia is being stupid and evil again.',
#   'tweet_lang': 'en',
#   'hashtags': [{'text': 'FakeNewsMedia', 'indices': [17, 31]}],
#   'mentions': [{'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [0, 16]}],
#   'tweet_urls': [],
#   'tweet_date': 'Fri Sep 06 14:35:33 +0000 2019',
#   'tweet_loc': None,
#   'tweet_id': 1169982471443820545,
#   'retweeted': False,
#   'replied_to_screen_name': 'realDonaldTrump'},
#  {'poi_name': 'realDonaldTrump',
#   'poi_id': 25073877,
#   'verified': False,
#   'country': '',
#   'replied_to_tweet_id': 1169981020634013696,
#   'replied_to_user_id': 25073877,
#   'tweet_text': '@realDonaldTrump Whose partner, what partner, where is this partner?',
#   'tweet_lang': 'en',
#   'hashtags': [],
#   'mentions': [{'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [0, 16]}],
#   'tweet_urls': [],
#   'tweet_date': 'Fri Sep 06 14:35:32 +0000 2019',
#   'tweet_loc': None,
#   'tweet_id': 1169982468578897920,
#   'retweeted': False,
#   'replied_to_screen_name': 'realDonaldTrump'}]

# %%
d
