# %%
import tweepy
import json
from tweepy import OAuthHandler, AppAuthHandler
from twarc import Twarc
import emoji
import pytz
import datetime

# %%
twitterKeys = {'consumer_key' : '57YoNBcWjCcqYaQ8DT1Syuwgb', 
              'consumer_secret':'5hykB2rsb3dojMkiWkvVWhs9juJPrWZYkFShG79yUKsQhdextT',
             'access_token':'884281851237367808-K6xR79CD77Lb5Iv90RXOqFNW4u5eMyZ',
             'access_secret': 'BnQmg8NG07wVQyupdPg7T2doK6sgVPvawuWdtkCy7n6fM'}

# authenticate
auth = AppAuthHandler(twitterKeys['consumer_key'],twitterKeys['consumer_secret'])

# %%
# create twarc objec
tObj = Twarc(twitterKeys['consumer_key'],twitterKeys['consumer_secret'],twitterKeys['access_token'],twitterKeys['access_secret'])

# create twitter api object
tapi = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

# %%
# function to extract relaed information from twitter data
def parse_tweet_data(tweet,reply_flag=False):
    # Extract only relevant data from the tweet json
    data = {'poi_name': tweet.get('user').get('screen_name'),
            'poi_id': tweet.get('user').get('id'),
            'verified': tweet.get('user').get('verified'),
            'country': tweet.get('user').get('location'),
            'replied_to_tweet_id': tweet.get('in_reply_to_status_id'),
            'replied_to_user_id': tweet.get('in_reply_to_user_id'),
            'tweet_text': tweet.get('full_text'),
            'tweet_lang': tweet.get('lang'),
            'hashtags': [h.get('text') for h in tweet.get('entities').get('hashtags')],
            'mentions': [m.get('screen_name') for m in tweet.get('entities')['user_mentions']],
            'tweet_urls': [u.get('url') for u in tweet.get('entities')['urls']],
            'tweet_date': tweet.get('created_at'),
            'tweet_loc': tweet.get('geo'),
            'retweeted': tweet.get('retweeted'),
            'replied_to_screen_name': tweet.get('in_reply_to_screen_name'),
            'tweet_emoticons':[e for e in tweet.get("full_text") if e in emoji.UNICODE_EMOJI],
            'reply_text': None
           }
    if reply_flag:
        data.update({'poi_name': tweet.get('in_reply_to_screen_name'),
                     'poi_id': tweet.get('in_reply_to_user_id'),
                     'reply_text':tweet.get('full_text'),
                    })
    # set country
    country_list = {"usa": ["realDonaldTrump", "KamalaHarris", "BernieSanders", "CoryBooker", "JoeBiden"], 
                    "india": ["narendramodi", "AmitShah", "PiyushGoyal", "rajnathsingh", "yadavakhilesh"],
                    "brazil": ["jairbolsonaro", "BolsonaroSP", "Haddad_Fernando", "LulaOficial", "dilmabr", "rodrigobocardi"]}

    for key,val in country_list.items():
        for person in val:
            if person == data.get("poi_name"):
                data.update({"country": key})
                
    # convert date to GMT
    gmt_date = datetime.datetime.strptime(data.get('tweet_date'), '%a %b %d %H:%M:%S +%f %Y')
    gmt_date = pytz.utc.localize(gmt_date)
    gmt_date = gmt_date.astimezone(pytz.timezone('GMT'))
    gmt_date = gmt_date.replace(microsecond=0, second=0, minute=0) + datetime.timedelta(hours=1)
    gmt_date = gmt_date.strftime('%Y-%m-%dT%H:%M:%SZ')

    data.update({'tweet_date': gmt_date})
        
    # update media
    try:
        data.update({'media_url': [mu.get('url') for mu in tweet.get('entities').get('media')]})
    except:
        pass
    
#     if "media" in tweet.get('entities').keys():
#         data.update({'media_url': [mu.get('url') for mu in tweet.get('entities').get('media')]})
#     else:
#         data.update({'media_url':[None]})    
    # combine data and tweet data
    data.update(tweet)
    return data

# %%
# function to search replies using tweepy
def search_replies(twitter_user,since_id,max_id,tweet):
    #print("twitterUser:", twitter_user, "sinceID:", since_id, 'max_id:', max_id)
    tweet_replies = []
#     dummy_value = 20000000
#     multiplier = 1
    i =0
    for reply in tweepy.Cursor(tapi.search,twitter_user,since_id=since_id,max_id=max_id, tweet_mode='extended').items(3000):
        i = i+1
        # get the in_reply_to_status_id
        verified_id = reply._json.get('in_reply_to_status_id')       
        
        if len(tweet_replies) < 21:
            if since_id == verified_id:
                tweet_replies.extend([parse_tweet_data(reply._json,reply_flag=True)])
        else:
            break
#     print("sinceID: ",since_id,"\t\t maxID: ", max_id)
    print("loopCount: ", i, "\t replyCount: ",len(tweet_replies), '\n')
    
#     if len(tweet_replies) < 21:
#         if max_id is None:
#             max_id = reply._json.get('id')
#         max_id = max_id + dummy_value * multiplier
#         multiplier = multiplier * 2    
#         search_replies(twitter_user,since_id,max_id,tweet)
    
    return tweet_replies

# %%
counter = 0
last_tweet_id = False
twitter_user = 'LulaOficial'
tweet_list = []
max_id = None
tweet_count = 0

while counter < 11:
    
    if last_tweet_id:
        tw = tapi.user_timeline(twitter_user, count=200, include_rts=True, tweet_mode='extended', max_id = max_id)
        
    else:
        last_tweet_id = True
        tw = tapi.user_timeline(twitter_user, count=200, include_rts=True, tweet_mode='extended')

    for tweet in tw:
        tweet_count = tweet_count + 1
        current_tweet_id = tweet._json.get("id")
        dummy_value = 20000000000
        multiplier = 1
        tweet_date_limit = (datetime.datetime.today() - tweet.created_at).days
        print("Tweet:", tweet_count,"\t ID: ", current_tweet_id,"\n")
        if tweet_date_limit < 7:
            tweet_replies = []
            #temp_list = []
            #tweet_replies = [parse_tweet_data(tweet._json)]
            # call function to search replies.
            #tweet_replies.extend(search_replies("to:{}".format(twitter_user) + " filter:replies", current_tweet_id,max_id,tweet))
            while len(tweet_replies) < 24 and multiplier < 35:
                #if max_id is None:
                #    max_id = tweet_replies[len(tweet_replies)-1].get('tweet_id')
                # call function to search replies.
                tweet_replies.extend(search_replies("to:{}".format(twitter_user) + " filter:replies", current_tweet_id,max_id,tweet))

                if len(tweet_replies) < 21:
                    max_id = max_id + dummy_value * multiplier
                    multiplier = multiplier * 2
                    print("Continue Search for replies with: ", multiplier, " multiplier")
                else:
                    break
                #temp_list = (search_replies(twitter_user,current_tweet_id,max_id,tweet))
                #if len(temp_list) > 21:
                #    tweet_replies.extend(temp_list)
            print("----------------------------------------------------------")
            if len(tweet_replies)>=20 and len(tweet_replies)<24:
                tweet_list.extend([parse_tweet_data(tweet._json)])
                tweet_list.extend(tweet_replies)
                print("Saved!")
        
            #for reply in tObj.replies(tweet._json):
            #if len(tweet_replies) > 20:
            #    tweet_list.extend(tweet_replies)
            #    break
            #else:
            #    tweet_replies.extend([parse_tweet_data(reply)])
            #    replyCount = replyCount + 1

            #print("Tweet ID: ", counter, "\t\t Total Replies:", replyCount)
        else:
#             tweet_list.extend([parse_tweet_data(tweet._json)])
            break
        max_id = current_tweet_id
        
        with open("crawledData/5DayCrawls/{}".format(twitter_user)+"5.json","w") as f:
            json.dump(tweet_list,f)
    counter = counter + 1
# Out:
# Tweet: 1 	 ID:  1173066570530205696
#
# loopCount:  63 	 replyCount:  0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-73ed50148082> in <module>
#      35
#      36                 if len(tweet_replies) < 21:
# ---> 37                     max_id = max_id + dummy_value * multiplier
#      38                     multiplier = multiplier * 2
#      39                     print("Continue Search for replies with: ", multiplier, " multiplier")
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'int'

# %%
len(tweet_list)
len(tweet_replies)

i=0
for c in tweet_list:
    try:
        if not c.get('replied_to_tweet_id'):
            i = i + 1
    except Exception as e:
        print (e, '\n', c)
print(i)

# %%
tweet_list[1]
# Out:
# {'poi_name': 'jairbolsonaro',
#  'poi_id': 128372940,
#  'verified': False,
#  'country': 'brazil',
#  'replied_to_tweet_id': 1171882119146147846,
#  'replied_to_user_id': 128372940,
#  'tweet_text': '@jairbolsonaro Privatiza tudo Sr Pres, furnas e Eletrobras antro político....',
#  'tweet_lang': 'pt',
#  'hashtags': [],
#  'mentions': ['jairbolsonaro'],
#  'tweet_urls': [],
#  'tweet_date': '2019-09-12T08:00:00Z',
#  'tweet_loc': None,
#  'retweeted': False,
#  'replied_to_screen_name': 'jairbolsonaro',
#  'tweet_emoticons': [],
#  'created_at': 'Thu Sep 12 07:55:07 +0000 2019',
#  'id': 1172056027539398656,
#  'id_str': '1172056027539398656',
#  'full_text': '@jairbolsonaro Privatiza tudo Sr Pres, furnas e Eletrobras antro político....',
#  'truncated': False,
#  'display_text_range': [15, 77],
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'jairbolsonaro',
#     'name': 'Jair M. Bolsonaro',
#     'id': 128372940,
#     'id_str': '128372940',
#     'indices': [0, 14]}],
#   'urls': []},
#  'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#  'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#  'in_reply_to_status_id': 1171882119146147846,
#  'in_reply_to_status_id_str': '1171882119146147846',
#  'in_reply_to_user_id': 128372940,
#  'in_reply_to_user_id_str': '128372940',
#  'in_reply_to_screen_name': 'jairbolsonaro',
#  'user': {'id': 1111695782682480640,
#   'id_str': '1111695782682480640',
#   'name': 'Juarez',
#   'screen_name': 'Juarez98857287',
#   'location': '',
#   'description': 'Valorizo a pasciencia e saber que desistir nem sempre significa fracassar...',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 13,
#   'friends_count': 74,
#   'listed_count': 0,
#   'created_at': 'Fri Mar 29 18:25:03 +0000 2019',
#   'favourites_count': 1551,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 158,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1130815311807172609/6Z8_cRoV_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1130815311807172609/6Z8_cRoV_normal.jpg',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': None,
#   'follow_request_sent': None,
#   'notifications': None,
#   'translator_type': 'none'},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'is_quote_status': False,
#  'retweet_count': 0,
#  'favorite_count': 0,
#  'favorited': False,
#  'lang': 'pt'}

# %%
tweet_list[16]
# Out:
# {'poi_name': 'realDonaldTrump',
#  'poi_id': 25073877,
#  'verified': False,
#  'country': 'usa',
#  'replied_to_tweet_id': 1170469621348098049,
#  'replied_to_user_id': 25073877,
#  'tweet_text': '@realDonaldTrump Donal Trump Afghanistan is the country of Taliban and  you do not belong to the people, why are you sitting there, Taliban can fight with you for 1000 years',
#  'tweet_lang': 'en',
#  'hashtags': [],
#  'mentions': [{'screen_name': 'realDonaldTrump',
#    'name': 'Donald J. Trump',
#    'id': 25073877,
#    'id_str': '25073877',
#    'indices': [0, 16]}],
#  'tweet_urls': [],
#  'tweet_date': '2019-09-08T04:00:00Z',
#  'tweet_loc': None,
#  'tweet_id': 1170533204689747969,
#  'retweeted': False,
#  'replied_to_screen_name': 'realDonaldTrump',
#  'tweet_emoticons': []}

# %%
storedTweet = tapi.user_timeline("TheWeirdWorld", count=100, include_rts=True, tweet_mode='extended')

data = storedTweet[15]._json
tweet_id = data.get('id')
previous_tweet_id = storedTweet[14]._json.get('id')
print(previous_tweet_id)

start_date = datetime.datetime.strptime(data.get('created_at'), "%a %b %d %H:%M:%S +%f %Y")
print("start_date: ", start_date, "\t tweet_id: ",tweet_id, '\n text: ', data.get('full_text'))
until = start_date + datetime.timedelta(days=1)
until = datetime.datetime.strftime(until, "%Y-%m-%d")

# datetime.datetime.strftime(until, "%Y-%m-%d")
temp = []
for i in tapi.search(q='@TheWeirdWorld filter:replies',since_id = data.get('id'), count=1000):
    check = i._json.get('created_at')
    print(i._json)
#     print(tweet_id == i._json.get('in_reply_to_status_id'))
    
    if (i._json.get('in_reply_to_status_id') == None):
        print (i._json)
        temp1 = i._json
        break
    if tweet_id == i._json.get('in_reply_to_status_id'):
        temp.extend([i._json])
        
#         print(temp.extend([i._json]))
#     check = datetime.datetime.strptime(data.get('created_at'), "%a %b %d %H:%M:%S +%f %Y")
#     check = datetime.datetime.strftime(check, "%Y-%m-%d")
# Out:
# 1170177623668002816
# start_date:  2019-09-07 02:04:00 	 tweet_id:  1170155729015201792
#  text:  When someone accuses you of being lazy, it’s almost always because you aren’t doing something they want you to do; so it’s a shaming tactic rather than constructive criticism.
# {'created_at': 'Sun Sep 08 05:52:08 +0000 2019', 'id': 1170575524885913600, 'id_str': '1170575524885913600', 'text': "@KenyanSide @lisaaryaa @TheWeirdWorld she doesn't like you ROMANTICALLY that's what you (i hope) don't understand t… https://t.co/Fezp66K6Rm", 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'KenyanSide', 'name': 'wHAT_dID_yOU_eXPECT?', 'id': 987955132502507520, 'id_str': '987955132502507520', 'indices': [0, 11]}, {'screen_name': 'lisaaryaa', 'name': 'jonquille 🌼', 'id': 983022862134054914, 'id_str': '983022862134054914', 'indices': [12, 22]}, {'screen_name': 'TheWeirdWorld', 'name': 'Shower Thoughts', 'id': 487736815, 'id_str': '487736815', 'indices': [23, 37]}], 'urls': [{'url': 'https://t.co/Fezp66K6Rm', 'expanded_url': 'https://twitter.com/i/web/status/1170575524885913600', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': 1170574659596824579, 'in_reply_to_status_id_str': '1170574659596824579', 'in_reply_to_user_id': 987955132502507520, 'in_reply_to_user_id_str': '987955132502507520', 'in_reply_to_screen_name': 'KenyanSide', 'user': {'id': 911327450, 'id_str': '911327450', 'name': 'genewildersleftweave', 'screen_name': 'Spacevillenllc', 'location': '', 'description': "You don't the power to defeat what makes me sleep so not even the ability to see it's face", 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 64, 'friends_count': 570, 'listed_count': 0, 'created_at': 'Sun Oct 28 23:33:00 +0000 2012', 'favourites_count': 11209, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 3841, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1004974730984730624/1xprbX4t_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1004974730984730624/1xprbX4t_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/911327450/1462801215', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}
# {'created_at': 'Sun Sep 08 05:49:23 +0000 2019', 'id': 1170574835489001472, 'id_str': '1170574835489001472', 'text': '@robfremming @TheWeirdWorld Awwww...poor girl', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'robfremming', 'name': 'Robert Fremming', 'id': 2509364994, 'id_str': '2509364994', 'indices': [0, 12]}, {'screen_name': 'TheWeirdWorld', 'name': 'Shower Thoughts', 'id': 487736815, 'id_str': '487736815', 'indices': [13, 27]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': 1170570355716644864, 'in_reply_to_status_id_str': '1170570355716644864', 'in_reply_to_user_id': 2509364994, 'in_reply_to_user_id_str': '2509364994', 'in_reply_to_screen_name': 'robfremming', 'user': {'id': 537972432, 'id_str': '537972432', 'name': 'Niraag® S 🏏', 'screen_name': 'niraag69', 'location': 'Mumbai West ', 'description': "Who says money can't buy happiness..You pay me and I 'll be the happiness for you", 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 446, 'friends_count': 363, 'listed_count': 21, 'created_at': 'Tue Mar 27 05:49:03 +0000 2012', 'favourites_count': 16958, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 28058, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '022330', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/962403341111209984/yEjEtXYS_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/962403341111209984/yEjEtXYS_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/537972432/1495307136', 'profile_link_color': 'B30042', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'EFEFEF', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}
# {'created_at': 'Sun Sep 08 05:48:41 +0000 2019', 'id': 1170574659596824579, 'id_str': '1170574659596824579', 'text': '@Spacevillenllc @lisaaryaa @TheWeirdWorld It’s just sad that you like her, she likes you, would like to date someon… https://t.co/96zIGjH3BP', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'Spacevillenllc', 'name': 'genewildersleftweave', 'id': 911327450, 'id_str': '911327450', 'indices': [0, 15]}, {'screen_name': 'lisaaryaa', 'name': 'jonquille 🌼', 'id': 983022862134054914, 'id_str': '983022862134054914', 'indices': [16, 26]}, {'screen_name': 'TheWeirdWorld', 'name': 'Shower Thoughts', 'id': 487736815, 'id_str': '487736815', 'indices': [27, 41]}], 'urls': [{'url': 'https://t.co/96zIGjH3BP', 'expanded_url': 'https://twitter.com/i/web/status/1170574659596824579', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': 1170572796793163776, 'in_reply_to_status_id_str': '1170572796793163776', 'in_reply_to_user_id': 911327450, 'in_reply_to_user_id_str': '911327450', 'in_reply_to_screen_name': 'Spacevillenllc', 'user': {'id': 987955132502507520, 'id_str': '987955132502507520', 'name': 'wHAT_dID_yOU_eXPECT?', 'screen_name': 'KenyanSide', 'location': 'Narok, Kenya', 'description': 'politics, human rights, sarcasm, reality, life sucks', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 84, 'friends_count': 195, 'listed_count': 0, 'created_at': 'Sun Apr 22 07:23:53 +0000 2018', 'favourites_count': 146, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 3689, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1156900122715967489/zkEaVz8P_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1156900122715967489/zkEaVz8P_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/987955132502507520/1526011644', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}
# {'created_at': 'Sun Sep 08 05:48:08 +0000 2019', 'id': 1170574518655602691, 'id_str': '1170574518655602691', 'text': '@SOUL_3SC4P3 @Simply_Vivianna @TheWeirdWorld There is an episode of Futurama about this. Fry finds the fossil of hi… https://t.co/4KkQAAEq1L', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'SOUL_3SC4P3', 'name': 'SOUL, Not Gina', 'id': 2848248792, 'id_str': '2848248792', 'indices': [0, 12]}, {'screen_name': 'Simply_Vivianna', 'name': 'Vivianna', 'id': 789844489812586496, 'id_str': '789844489812586496', 'indices': [13, 29]}, {'screen_name': 'TheWeirdWorld', 'name': 'Shower Thoughts', 'id': 487736815, 'id_str': '487736815', 'indices': [30, 44]}], 'urls': [{'url': 'https://t.co/4KkQAAEq1L', 'expanded_url': 'https://twitter.com/i/web/status/1170574518655602691', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': 1170550519170945025, 'in_reply_to_status_id_str': '1170550519170945025', 'in_reply_to_user_id': 2848248792, 'in_reply_to_user_id_str': '2848248792', 'in_reply_to_screen_name': 'SOUL_3SC4P3', 'user': {'id': 1035471407285710849, 'id_str': '1035471407285710849', 'name': "Jorin 'Bishop' Z", 'screen_name': 'FJozz45', 'location': 'South East, England', 'description': 'I take many photographs and play rural and nature based RPG games. I upload to instagram and youtube. I broadcast to Twitch', 'url': 'https://t.co/OsSxfgDeoa', 'entities': {'url': {'urls': [{'url': 'https://t.co/OsSxfgDeoa', 'expanded_url': 'https://www.instagram.com/jorin_zankl', 'display_url': 'instagram.com/jorin_zankl', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 131, 'friends_count': 346, 'listed_count': 1, 'created_at': 'Fri Aug 31 10:16:36 +0000 2018', 'favourites_count': 4750, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 4413, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1166359456797593600/yc-kBpKt_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1166359456797593600/yc-kBpKt_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1035471407285710849/1567075354', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}
# {'created_at': 'Sun Sep 08 05:44:49 +0000 2019', 'id': 1170573685649858561, 'id_str': '1170573685649858561', 'text': '@rford2112 @TheWeirdWorld Yes but the bleeding heart liberals wont let that happen. They want a safe zone for all to go to.', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'rford2112', 'name': 'Rob Ford', 'id': 187580639, 'id_str': '187580639', 'indices': [0, 10]}, {'screen_name': 'TheWeirdWorld', 'name': 'Shower Thoughts', 'id': 487736815, 'id_str': '487736815', 'indices': [11, 25]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': 1170508476025622529, 'in_reply_to_status_id_str': '1170508476025622529', 'in_reply_to_user_id': 187580639, 'in_reply_to_user_id_str': '187580639', 'in_reply_to_screen_name': 'rford2112', 'user': {'id': 2509364994, 'id_str': '2509364994', 'name': 'Robert Fremming', 'screen_name': 'robfremming', 'location': 'Florida, USA', 'description': "Trying to have fun in life. A KISS fan. Hair bands from 80's.", 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 198, 'friends_count': 76, 'listed_count': 6, 'created_at': 'Tue May 20 05:27:19 +0000 2014', 'favourites_count': 181, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 16371, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/978984509264793600/WclYH5OB_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/978984509264793600/WclYH5OB_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2509364994/1407529169', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}
# {'created_at': 'Sun Sep 08 05:43:30 +0000 2019', 'id': 1170573353083703296, 'id_str': '1170573353083703296', 'text': '@TheWeirdWorld Yea I agree, but then the movie be over in like ten minutes.', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'TheWeirdWorld', 'name': 'Shower Thoughts', 'id': 487736815, 'id_str': '487736815', 'indices': [0, 14]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': 1170502763664629760, 'in_reply_to_status_id_str': '1170502763664629760', 'in_reply_to_user_id': 487736815, 'in_reply_to_user_id_str': '487736815', 'in_reply_to_screen_name': 'TheWeirdWorld', 'user': {'id': 2509364994, 'id_str': '2509364994', 'name': 'Robert Fremming', 'screen_name': 'robfremming', 'location': 'Florida, USA', 'description': "Trying to have fun in life. A KISS fan. Hair bands from 80's.", 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 198, 'friends_count': 76, 'listed_count': 6, 'created_at': 'Tue May 20 05:27:19 +0000 2014', 'favourites_count': 181, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 16371, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/978984509264793600/WclYH5OB_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/978984509264793600/WclYH5OB_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2509364994/1407529169', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 1, 'favorited': False, 'retweeted': False, 'lang': 'en'}
# {'created_at': 'Sun Sep 08 05:41:17 +0000 2019', 'id': 1170572796793163776, 'id_str': '1170572796793163776', 'text': "@KenyanSide @lisaaryaa @TheWeirdWorld Like you not you because liking someones qualities doesn't mean you want to d… https://t.co/Stb3zUbZeg", 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'KenyanSide', 'name': 'wHAT_dID_yOU_eXPECT?', 'id': 987955132502507520, 'id_str': '987955132502507520', 'indices': [0, 11]}, {'screen_name': 'lisaaryaa', 'name': 'jonquille 🌼', 'id': 983022862134054914, 'id_str': '983022862134054914', 'indices': [12, 22]}, {'screen_name': 'TheWeirdWorld', 'name': 'Shower Thoughts', 'id': 487736815, 'id_str': '487736815', 'indices': [23, 37]}], 'urls': [{'url': 'https://t.co/Stb3zUbZeg', 'expanded_url': 'https://twitter.com/i/web/status/1170572796793163776', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': 1170569863217201152, 'in_reply_to_status_id_str': '1170569863217201152', 'in_reply_to_user_id': 987955132502507520, 'in_reply_to_user_id_str': '987955132502507520', 'in_reply_to_screen_name': 'KenyanSide', 'user': {'id': 911327450, 'id_str': '911327450', 'name': 'genewildersleftweave', 'screen_name': 'Spacevillenllc', 'location': '', 'description': "You don't the power to defeat what makes me sleep so not even the ability to see it's face", 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 64, 'friends_count': 570, 'listed_count': 0, 'created_at': 'Sun Oct 28 23:33:00 +0000 2012', 'favourites_count': 11209, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 3841, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1004974730984730624/1xprbX4t_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1004974730984730624/1xprbX4t_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/911327450/1462801215', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}
# {'created_at': 'Sun Sep 08 05:39:13 +0000 2019', 'id': 1170572278033260544, 'id_str': '1170572278033260544', 'text': "@SpicyWoodenBoi @TheWeirdWorld It's probably his hair", 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'SpicyWoodenBoi', 'name': 'M3RK CHA0S news anchor, quartermaster & councilman', 'id': 821090233580130304, 'id_str': '821090233580130304', 'indices': [0, 15]}, {'screen_name': 'TheWeirdWorld', 'name': 'Shower Thoughts', 'id': 487736815, 'id_str': '487736815', 'indices': [16, 30]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': 1170535957726224384, 'in_reply_to_status_id_str': '1170535957726224384', 'in_reply_to_user_id': 821090233580130304, 'in_reply_to_user_id_str': '821090233580130304', 'in_reply_to_screen_name': 'SpicyWoodenBoi', 'user': {'id': 911327450, 'id_str': '911327450', 'name': 'genewildersleftweave', 'screen_name': 'Spacevillenllc', 'location': '', 'description': "You don't the power to defeat what makes me sleep so not even the ability to see it's face", 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 64, 'friends_count': 570, 'listed_count': 0, 'created_at': 'Sun Oct 28 23:33:00 +0000 2012', 'favourites_count': 11209, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 3841, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1004974730984730624/1xprbX4t_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1004974730984730624/1xprbX4t_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/911327450/1462801215', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}
# {'created_at': 'Sun Sep 08 05:31:56 +0000 2019', 'id': 1170570441670438912, 'id_str': '1170570441670438912', 'text': '@reneedhyani @TheWeirdWorld Me too.', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'reneedhyani', 'name': 'ReneeDhyani', 'id': 251996565, 'id_str': '251996565', 'indices': [0, 12]}, {'screen_name': 'TheWeirdWorld', 'name': 'Shower Thoughts', 'id': 487736815, 'id_str': '487736815', 'indices': [13, 27]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': 1170407166320054272, 'in_reply_to_status_id_str': '1170407166320054272', 'in_reply_to_user_id': 251996565, 'in_reply_to_user_id_str': '251996565', 'in_reply_to_screen_name': 'reneedhyani', 'user': {'id': 2509364994, 'id_str': '2509364994', 'name': 'Robert Fremming', 'screen_name': 'robfremming', 'location': 'Florida, USA', 'description': "Trying to have fun in life. A KISS fan. Hair bands from 80's.", 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 198, 'friends_count': 76, 'listed_count': 6, 'created_at': 'Tue May 20 05:27:19 +0000 2014', 'favourites_count': 181, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 16371, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/978984509264793600/WclYH5OB_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/978984509264793600/WclYH5OB_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2509364994/1407529169', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}
# {'created_at': 'Sun Sep 08 05:31:35 +0000 2019', 'id': 1170570355716644864, 'id_str': '1170570355716644864', 'text': '@niraag69 @TheWeirdWorld Well after a 30 minute sexercise then we both sleep naked until time arises for 2nd wave of sexercise.', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'niraag69', 'name': 'Niraag® S 🏏', 'id': 537972432, 'id_str': '537972432', 'indices': [0, 9]}, {'screen_name': 'TheWeirdWorld', 'name': 'Shower Thoughts', 'id': 487736815, 'id_str': '487736815', 'indices': [10, 24]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': 1170405079423176704, 'in_reply_to_status_id_str': '1170405079423176704', 'in_reply_to_user_id': 537972432, 'in_reply_to_user_id_str': '537972432', 'in_reply_to_screen_name': 'niraag69', 'user': {'id': 2509364994, 'id_str': '2509364994', 'name': 'Robert Fremming', 'screen_name': 'robfremming', 'location': 'Florida, USA', 'description': "Trying to have fun in life. A KISS fan. Hair bands from 80's.", 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 198, 'friends_count': 76, 'listed_count': 6, 'created_at': 'Tue May 20 05:27:19 +0000 2014', 'favourites_count': 181, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 16371, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/978984509264793600/WclYH5OB_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/978984509264793600/WclYH5OB_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2509364994/1407529169', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}
# {'created_at': 'Sun Sep 08 05:29:38 +0000 2019', 'id': 1170569863217201152, 'id_str': '1170569863217201152', 'text': '@lisaaryaa @TheWeirdWorld And she’s struggling to find a boyfriend who is like you.....', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'lisaaryaa', 'name': 'jonquille 🌼', 'id': 983022862134054914, 'id_str': '983022862134054914', 'indices': [0, 10]}, {'screen_name': 'TheWeirdWorld', 'name': 'Shower Thoughts', 'id': 487736815, 'id_str': '487736815', 'indices': [11, 25]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': 1170545178286972929, 'in_reply_to_status_id_str': '1170545178286972929', 'in_reply_to_user_id': 983022862134054914, 'in_reply_to_user_id_str': '983022862134054914', 'in_reply_to_screen_name': 'lisaaryaa', 'user': {'id': 987955132502507520, 'id_str': '987955132502507520', 'name': 'wHAT_dID_yOU_eXPECT?', 'screen_name': 'KenyanSide', 'location': 'Narok, Kenya', 'description': 'politics, human rights, sarcasm, reality, life sucks', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 84, 'friends_count': 195, 'listed_count': 0, 'created_at': 'Sun Apr 22 07:23:53 +0000 2018', 'favourites_count': 146, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 3689, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1156900122715967489/zkEaVz8P_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1156900122715967489/zkEaVz8P_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/987955132502507520/1526011644', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}
# {'created_at': 'Sun Sep 08 05:28:44 +0000 2019', 'id': 1170569638582902785, 'id_str': '1170569638582902785', 'text': '@bumtweets @TheWeirdWorld Could be. She might fall from the ceiling and land directly on it. It worked from Dennis Rodman.', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'bumtweets', 'name': 'bumtweets', 'id': 69017991, 'id_str': '69017991', 'indices': [0, 10]}, {'screen_name': 'TheWeirdWorld', 'name': 'Shower Thoughts', 'id': 487736815, 'id_str': '487736815', 'indices': [11, 25]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': 1170406965182439431, 'in_reply_to_status_id_str': '1170406965182439431', 'in_reply_to_user_id': 69017991, 'in_reply_to_user_id_str': '69017991', 'in_reply_to_screen_name': 'bumtweets', 'user': {'id': 2509364994, 'id_str': '2509364994', 'name': 'Robert Fremming', 'screen_name': 'robfremming', 'location': 'Florida, USA', 'description': "Trying to have fun in life. A KISS fan. Hair bands from 80's.", 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 198, 'friends_count': 76, 'listed_count': 6, 'created_at': 'Tue May 20 05:27:19 +0000 2014', 'favourites_count': 181, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 16371, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/978984509264793600/WclYH5OB_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/978984509264793600/WclYH5OB_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2509364994/1407529169', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}
# {'created_at': 'Sun Sep 08 05:24:59 +0000 2019', 'id': 1170568695128739840, 'id_str': '1170568695128739840', 'text': '@IamCece2800 @CRC_Katya @TheWeirdWorld @neonfox369 @SydnieFeugill @EeveeQueen1 @s8n @fordtaurusgurl 😿', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'IamCece2800', 'name': 'Cece🏳️\u200d🌈🌺', 'id': 728695061102403584, 'id_str': '728695061102403584', 'indices': [0, 12]}, {'screen_name': 'CRC_Katya', 'name': 'Katya Petrikov (a live-tweeted comic)', 'id': 124090563, 'id_str': '124090563', 'indices': [13, 23]}, {'screen_name': 'TheWeirdWorld', 'name': 'Shower Thoughts', 'id': 487736815, 'id_str': '487736815', 'indices': [24, 38]}, {'screen_name': 'neonfox369', 'name': 'rats! At the Disco', 'id': 733096937356922880, 'id_str': '733096937356922880', 'indices': [39, 50]}, {'screen_name': 'SydnieFeugill', 'name': 'Sy', 'id': 924028785762201600, 'id_str': '924028785762201600', 'indices': [51, 65]}, {'screen_name': 'EeveeQueen1', 'name': 'Mischief', 'id': 900144721720377345, 'id_str': '900144721720377345', 'indices': [66, 78]}, {'screen_name': 's8n', 'name': 'Satan', 'id': 13615722, 'id_str': '13615722', 'indices': [79, 83]}, {'screen_name': 'fordtaurusgurl', 'name': 'ava', 'id': 827997759491997699, 'id_str': '827997759491997699', 'indices': [84, 99]}], 'urls': []}, 'metadata': {'iso_language_code': 'und', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': 1169932030043463681, 'in_reply_to_status_id_str': '1169932030043463681', 'in_reply_to_user_id': 728695061102403584, 'in_reply_to_user_id_str': '728695061102403584', 'in_reply_to_screen_name': 'IamCece2800', 'user': {'id': 1030288388736339970, 'id_str': '1030288388736339970', 'name': 'Darling', 'screen_name': 'BreezyBoo116', 'location': 'Behind you', 'description': 'I draw animals🐶🐱\nArt trades: OPEN\nCommissions: OPEN\nSylveon is best pokemon\nIcon by ddr0p-dd3ad on da\n\nEnjoy the small things in life', 'url': 'https://t.co/iIG3sMMAX4', 'entities': {'url': {'urls': [{'url': 'https://t.co/iIG3sMMAX4', 'expanded_url': 'https://www.youtube.com/channel/UCtA0fSTi9R9Bwz1I9BAZwXQ?view_as=subscriber', 'display_url': 'youtube.com/channel/UCtA0f…', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 13, 'friends_count': 91, 'listed_count': 0, 'created_at': 'Fri Aug 17 03:01:08 +0000 2018', 'favourites_count': 7471, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 210, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1170525436708839425/IFelcEe-_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1170525436708839425/IFelcEe-_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1030288388736339970/1567909987', 'profile_link_color': '981CEB', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'und'}
# {'created_at': 'Sun Sep 08 05:23:34 +0000 2019', 'id': 1170568335945322496, 'id_str': '1170568335945322496', 'text': '@TheWeirdWorld I miss my dog', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'TheWeirdWorld', 'name': 'Shower Thoughts', 'id': 487736815, 'id_str': '487736815', 'indices': [0, 14]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': 1170547308460740608, 'in_reply_to_status_id_str': '1170547308460740608', 'in_reply_to_user_id': 487736815, 'in_reply_to_user_id_str': '487736815', 'in_reply_to_screen_name': 'TheWeirdWorld', 'user': {'id': 3123543578, 'id_str': '3123543578', 'name': 'JSD24K', 'screen_name': 'jsd24K', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 18, 'friends_count': 178, 'listed_count': 0, 'created_at': 'Wed Apr 01 08:42:32 +0000 2015', 'favourites_count': 1654, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 296, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1160975921630863360/Y_kiqzKD_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1160975921630863360/Y_kiqzKD_normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}
# {'created_at': 'Sun Sep 08 05:22:38 +0000 2019', 'id': 1170568103278694400, 'id_str': '1170568103278694400', 'text': '@TheWeirdWorld Or maybe they hope for one?', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'TheWeirdWorld', 'name': 'Shower Thoughts', 'id': 487736815, 'id_str': '487736815', 'indices': [0, 14]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': 1170404366521643009, 'in_reply_to_status_id_str': '1170404366521643009', 'in_reply_to_user_id': 487736815, 'in_reply_to_user_id_str': '487736815', 'in_reply_to_screen_name': 'TheWeirdWorld', 'user': {'id': 735698394, 'id_str': '735698394', 'name': 'AussiePip', 'screen_name': 'amadItalian', 'location': 'Brisbane, Queensland', 'description': 'Crypto enthusiast', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 205, 'friends_count': 198, 'listed_count': 0, 'created_at': 'Fri Aug 03 23:13:09 +0000 2012', 'favourites_count': 7278, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 1963, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1006467446159523840/9Qoeuq6Q_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1006467446159523840/9Qoeuq6Q_normal.jpg', 'profile_link_color': '1B95E0', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}
# {'created_at': 'Sun Sep 08 05:21:12 +0000 2019', 'id': 1170567742740516867, 'id_str': '1170567742740516867', 'text': "@TheWeirdWorld That's why we think god never dies.", 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'TheWeirdWorld', 'name': 'Shower Thoughts', 'id': 487736815, 'id_str': '487736815', 'indices': [0, 14]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': 1170547308460740608, 'in_reply_to_status_id_str': '1170547308460740608', 'in_reply_to_user_id': 487736815, 'in_reply_to_user_id_str': '487736815', 'in_reply_to_screen_name': 'TheWeirdWorld', 'user': {'id': 2458418102, 'id_str': '2458418102', 'name': 'Rahul Kandpal', 'screen_name': 'rahulkandpal30', 'location': 'Delhi', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 9, 'friends_count': 217, 'listed_count': 0, 'created_at': 'Tue Apr 22 16:53:03 +0000 2014', 'favourites_count': 89, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 22, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': True, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}
# {'created_at': 'Sun Sep 08 05:09:29 +0000 2019', 'id': 1170564792366641152, 'id_str': '1170564792366641152', 'text': '@TheWeirdWorld I don’t 😂 but the other night a spider crawled on me so I’ve been fully dressed in the bed since. I’m prepared now 😇', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'TheWeirdWorld', 'name': 'Shower Thoughts', 'id': 487736815, 'id_str': '487736815', 'indices': [0, 14]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': 1170404366521643009, 'in_reply_to_status_id_str': '1170404366521643009', 'in_reply_to_user_id': 487736815, 'in_reply_to_user_id_str': '487736815', 'in_reply_to_screen_name': 'TheWeirdWorld', 'user': {'id': 308166574, 'id_str': '308166574', 'name': 'Something about Ari', 'screen_name': 'Murda_Moosh', 'location': '', 'description': 'GOD 1st☝🏾️. r.i.p day-day, r.i.p Dario🙏🏾', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 3152, 'friends_count': 1793, 'listed_count': 37, 'created_at': 'Mon May 30 23:11:25 +0000 2011', 'favourites_count': 103688, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 229536, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '0A070A', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1146977008540356608/fVR5WW96_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1146977008540356608/fVR5WW96_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/308166574/1355599421', 'profile_link_color': 'D117BB', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '215AEB', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}
# ...
# {'created_at': 'Sun Sep 08 00:42:21 +0000 2019', 'id': 1170497565579718656, 'id_str': '1170497565579718656', 'text': '@TheWeirdWorld OMG!, LOL, 🤣', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'TheWeirdWorld', 'name': 'Shower Thoughts', 'id': 487736815, 'id_str': '487736815', 'indices': [0, 14]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': 1170471559976366080, 'in_reply_to_status_id_str': '1170471559976366080', 'in_reply_to_user_id': 487736815, 'in_reply_to_user_id_str': '487736815', 'in_reply_to_screen_name': 'TheWeirdWorld', 'user': {'id': 939003129860726785, 'id_str': '939003129860726785', 'name': 'sherry johnson', 'screen_name': 'wildflowers1172', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 317, 'friends_count': 95, 'listed_count': 0, 'created_at': 'Fri Dec 08 05:26:06 +0000 2017', 'favourites_count': 14414, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 22100, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1120558592040607746/UxGKEdNz_normal.png', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1120558592040607746/UxGKEdNz_normal.png', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/939003129860726785/1556001998', 'profile_link_color': '1B95E0', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}
# {'created_at': 'Sun Sep 08 00:42:12 +0000 2019', 'id': 1170497531593318401, 'id_str': '1170497531593318401', 'text': '@computer_poppy @Idontknowmmkay @TheWeirdWorld ᵏ', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'computer_poppy', 'name': '💕 𝕮𝖔𝖒𝖕𝖚𝖙𝖊𝖗 💕', 'id': 967228443116089345, 'id_str': '967228443116089345', 'indices': [0, 15]}, {'screen_name': 'Idontknowmmkay', 'name': 'Mai', 'id': 1031200216303722496, 'id_str': '1031200216303722496', 'indices': [16, 31]}, {'screen_name': 'TheWeirdWorld', 'name': 'Shower Thoughts', 'id': 487736815, 'id_str': '487736815', 'indices': [32, 46]}], 'urls': []}, 'metadata': {'iso_language_code': 'und', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': 1170492972724576256, 'in_reply_to_status_id_str': '1170492972724576256', 'in_reply_to_user_id': 967228443116089345, 'in_reply_to_user_id_str': '967228443116089345', 'in_reply_to_screen_name': 'computer_poppy', 'user': {'id': 772545146089078785, 'id_str': '772545146089078785', 'name': 'Rhett Robin', 'screen_name': 'sour_vice', 'location': 'United States', 'description': 'oh', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 17, 'friends_count': 93, 'listed_count': 0, 'created_at': 'Sun Sep 04 21:21:30 +0000 2016', 'favourites_count': 780, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 385, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1154432328971821056/aKg4XZK8_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1154432328971821056/aKg4XZK8_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/772545146089078785/1566235633', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 5, 'favorited': False, 'retweeted': False, 'lang': 'und'}
# {'created_at': 'Sun Sep 08 00:26:10 +0000 2019', 'id': 1170493492600233984, 'id_str': '1170493492600233984', 'text': '@TheWeirdWorld 🤣🤣🤣 I feel guilty', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'TheWeirdWorld', 'name': 'Shower Thoughts', 'id': 487736815, 'id_str': '487736815', 'indices': [0, 14]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': 1170487666359582720, 'in_reply_to_status_id_str': '1170487666359582720', 'in_reply_to_user_id': 487736815, 'in_reply_to_user_id_str': '487736815', 'in_reply_to_screen_name': 'TheWeirdWorld', 'user': {'id': 109926348, 'id_str': '109926348', 'name': 'SixTimes Champions 🏆', 'screen_name': 'aleemkumi', 'location': '', 'description': 'Managing Consultant of Aliska (Business Advisory). Interests: Finance, Tech, NTO, Liverpool, Music and Art', 'url': 'https://t.co/2gymuzpdzC', 'entities': {'url': {'urls': [{'url': 'https://t.co/2gymuzpdzC', 'expanded_url': 'http://www.aliskaconsult.com', 'display_url': 'aliskaconsult.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 1195, 'friends_count': 1096, 'listed_count': 6, 'created_at': 'Sat Jan 30 18:46:17 +0000 2010', 'favourites_count': 16319, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 38760, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '352726', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme5/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme5/bg.gif', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1148602486212702208/sSF2zOdd_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1148602486212702208/sSF2zOdd_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/109926348/1564355859', 'profile_link_color': 'D02B55', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '99CC33', 'profile_text_color': '3E4415', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 1, 'favorited': False, 'retweeted': False, 'lang': 'en'}
# {'created_at': 'Sun Sep 08 00:24:06 +0000 2019', 'id': 1170492972724576256, 'id_str': '1170492972724576256', 'text': '@Idontknowmmkay @TheWeirdWorld it really is, especially if it’s lowercase then that’s a whole different kind of ins… https://t.co/MpvhEkmu1I', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'Idontknowmmkay', 'name': 'Mai', 'id': 1031200216303722496, 'id_str': '1031200216303722496', 'indices': [0, 15]}, {'screen_name': 'TheWeirdWorld', 'name': 'Shower Thoughts', 'id': 487736815, 'id_str': '487736815', 'indices': [16, 30]}], 'urls': [{'url': 'https://t.co/MpvhEkmu1I', 'expanded_url': 'https://twitter.com/i/web/status/1170492972724576256', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': 1170490373824798720, 'in_reply_to_status_id_str': '1170490373824798720', 'in_reply_to_user_id': 1031200216303722496, 'in_reply_to_user_id_str': '1031200216303722496', 'in_reply_to_screen_name': 'Idontknowmmkay', 'user': {'id': 967228443116089345, 'id_str': '967228443116089345', 'name': '💕 𝕮𝖔𝖒𝖕𝖚𝖙𝖊𝖗 💕', 'screen_name': 'computer_poppy', 'location': 'Internet', 'description': 'received Salvation from @poppy on February 1st in Philadelphia, PA. 💕 ✨', 'url': 'https://t.co/kSA3aIwww3', 'entities': {'url': {'urls': [{'url': 'https://t.co/kSA3aIwww3', 'expanded_url': 'http://poppy.church', 'display_url': 'poppy.church', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 315, 'friends_count': 486, 'listed_count': 0, 'created_at': 'Sat Feb 24 02:43:25 +0000 2018', 'favourites_count': 3298, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 2846, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1164570531393363970/k29OyBC8_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1164570531393363970/k29OyBC8_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/967228443116089345/1567812780', 'profile_link_color': 'C0C0C0', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 5, 'favorited': False, 'retweeted': False, 'lang': 'en'}
# {'created_at': 'Sun Sep 08 00:17:24 +0000 2019', 'id': 1170491289093181441, 'id_str': '1170491289093181441', 'text': '@TheWeirdWorld "Duly noted" *', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'TheWeirdWorld', 'name': 'Shower Thoughts', 'id': 487736815, 'id_str': '487736815', 'indices': [0, 14]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': 1170487666359582720, 'in_reply_to_status_id_str': '1170487666359582720', 'in_reply_to_user_id': 487736815, 'in_reply_to_user_id_str': '487736815', 'in_reply_to_screen_name': 'TheWeirdWorld', 'user': {'id': 4808054241, 'id_str': '4808054241', 'name': 'Mustafa', 'screen_name': 'MusternAR', 'location': '', 'description': 'Science, coffee and laughter.', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 12, 'friends_count': 48, 'listed_count': 1, 'created_at': 'Thu Jan 14 22:11:13 +0000 2016', 'favourites_count': 105, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 385, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1149996052508004352/KsmFT6QY_normal.png', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1149996052508004352/KsmFT6QY_normal.png', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4808054241/1530841212', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 1, 'favorite_count': 2, 'favorited': False, 'retweeted': False, 'lang': 'en'}

# %%
var = "yes"
print("to:{}".format(var)+"NO")

# %%
temp1
# Out:
# []
